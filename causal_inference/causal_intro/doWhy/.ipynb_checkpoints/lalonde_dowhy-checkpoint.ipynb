# %%
import dowhy.api
import pandas as pd
from dowhy import CausalModel
lalonde=pd.read_csv("lalonde.csv")

# %%
#dowhy makes graphs based on inputs/outputs. Adds a unobserved confounders node. Automated graph generation
#feeds all inputs into treatment and outcome(because the inuputs were identified as common causes) and adds an unobserved confounders node to outcome and treatment A->Y where A=treatment
#and Y=outcome. 
model=CausalModel(data=lalonde
                  ,treatment="treat",outcome="re78",
                  common_causes='nodegr+black+hisp+age+educ+married'.split('+'))
model.view_model()
from IPython.display import Image,display
display(Image(filename="causal_model.png"))
# Out:
# WARNING:dowhy.causal_model:Causal Graph not provided. DoWhy will construct a graph based on data inputs.
# INFO:dowhy.causal_graph:If this is observed data (not from a randomized experiment), there might always be missing confounders. Adding a node named "Unobserved Confounders" to reflect this.
# INFO:dowhy.causal_model:Model to find the causal effect of treatment ['treat'] on outcome ['re78']

# %%
identified_estimand = model.identify_effect()
print(identified_estimand)
# Out:
# INFO:dowhy.causal_identifier:Common causes of treatment and outcome:['married', 'educ', 'black', 'hisp', 'nodegr', 'age', 'U']
# WARNING:dowhy.causal_identifier:If this is observed data (not from a randomized experiment), there might always be missing confounders. Causal effect cannot be identified perfectly.
# WARN: Do you want to continue by ignoring any unobserved confounders? (use proceed_when_unidentifiable=True to disable this prompt) [y/n] y
# INFO:dowhy.causal_identifier:Instrumental variables for treatment and outcome:[]
# Estimand type: nonparametric-ate
# ### Estimand : 1
# Estimand name: backdoor
# Estimand expression:
#    d
# ────────(Expectation(re78|married,educ,black,hisp,nodegr,age))
# d[treat]
# Estimand assumption 1, Unconfoundedness: If U→{treat} and U→re78 then P(re78|treat,married,educ,black,hisp,nodegr,age,U) = P(re78|treat,married,educ,black,hisp,nodegr,age)
# ### Estimand : 2
# Estimand name: iv
# No such variable found!

# %%
propensity_strat_estimate = model.estimate_effect(identified_estimand,
                                 method_name="backdoor.dowhy.propensity_score_stratification",
                                                  target_name="")

print(propensity_strat_estimate)
# Out:
# ERROR:dowhy.causal_estimator:Propensity score methods are applicable only for binary treatments
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# <ipython-input-24-05d2304a45fc> in <module>
#       1 propensity_strat_estimate = model.estimate_effect(identified_estimand,
# ----> 2                                  method_name="backdoor.dowhy.propensity_score_stratification")
#       3
#       4 print(propensity_strat_estimate)
#
# ~/miniconda3/envs/covid/lib/python3.7/site-packages/dowhy/causal_model.py in estimate_effect(self, identified_estimand, method_name, control_value, treatment_value, test_significance, evaluate_effect_strength, confidence_intervals, target_units, effect_modifiers, method_params)
#     228                 target_units = target_units,
#     229                 effect_modifiers = effect_modifiers,
# --> 230                 params=method_params
#     231             )
#     232             estimate = causal_estimator.estimate_effect()
#
# ~/miniconda3/envs/covid/lib/python3.7/site-packages/dowhy/causal_estimators/propensity_score_stratification_estimator.py in __init__(self, num_strata, clipping_threshold, *args, **kwargs)
#      14
#      15     def __init__(self, *args, num_strata=50, clipping_threshold=10, **kwargs):
# ---> 16         super().__init__(*args,  **kwargs)
#      17
#      18         self.logger.info("INFO: Using Propensity Score Stratification Estimator")
#
# ~/miniconda3/envs/covid/lib/python3.7/site-packages/dowhy/causal_estimators/propensity_score_estimator.py in __init__(self, *args, **kwargs)
#      19             error_msg = "Propensity score methods are applicable only for binary treatments"
#      20             self.logger.error(error_msg)
# ---> 21             raise Exception(error_msg)
#      22
#      23         self.logger.debug("Back-door variables used:" +
#
# Exception: Propensity score methods are applicable only for binary treatments

# %%
do_df = lalonde.causal.do(x='treat',
                          outcome='re78',
                          common_causes=['nodegr', 'black', 'hisp', 'age', 'educ', 'married'],
                          variable_types={'age': 'c', 'educ':'c', 'black': 'd', 'hisp': 'd',
                                          'married': 'd', 'nodegr': 'd','re78': 'c', 'treat': 'b'})
# Out:
# WARNING:dowhy.causal_model:Causal Graph not provided. DoWhy will construct a graph based on data inputs.
# INFO:dowhy.causal_graph:If this is observed data (not from a randomized experiment), there might always be missing confounders. Adding a node named "Unobserved Confounders" to reflect this.
# INFO:dowhy.causal_model:Model to find the causal effect of treatment ['treat'] on outcome ['re78']
# INFO:dowhy.causal_identifier:Common causes of treatment and outcome:['married', 'educ', 'black', 'hisp', 'nodegr', 'age', 'U']
# WARNING:dowhy.causal_identifier:If this is observed data (not from a randomized experiment), there might always be missing confounders. Causal effect cannot be identified perfectly.
# WARN: Do you want to continue by ignoring any unobserved confounders? (use proceed_when_unidentifiable=True to disable this prompt) [y/n] y
# INFO:dowhy.causal_identifier:Instrumental variables for treatment and outcome:[]
# INFO:dowhy.do_sampler:Using WeightingSampler for do sampling.
# INFO:dowhy.do_sampler:Caution: do samplers assume iid data.

# %%
do_df.view_model(layout="dot")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-17-9113fd2593bf> in <module>
# ----> 1 do_df.view_model(layout="dot")
#
# ~/miniconda3/envs/covid/lib/python3.7/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5273                 return self[name]
# -> 5274             return object.__getattribute__(self, name)
#    5275
#    5276     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'view_model'

# %%
print(lalonde.head())
print("-------------")
print(do_df.head())
# Out:
#    age  educ  black  hisp  married  nodegr  re74  re75      re78  u74  u75  \
# 1   37    11      1     0        1       1   0.0   0.0   9930.05    1    1
# 2   22     9      0     1        0       1   0.0   0.0   3595.89    1    1
# 3   30    12      1     0        0       0   0.0   0.0  24909.50    1    1
# 4   27    11      1     0        0       1   0.0   0.0   7506.15    1    1
# 5   33     8      1     0        0       1   0.0   0.0    289.79    1    1
#
#    treat
# 1      1
# 2      1
# 3      1
# 4      1
# 5      1
# -------------
#    age  educ  black  hisp  married  nodegr  re74  re75     re78  u74  u75  \
# 1   28     8      0     0        0       1   0.0   0.0  8190.42    1    1
# 2   18     8      1     0        0       1   0.0   0.0     0.00    1    1
# 3   29     8      1     0        0       1   0.0   0.0     0.00    1    1
# 4   42    10      1     0        0       1   0.0   0.0  6930.34    1    1
# 5   24    11      1     0        0       1   0.0   0.0  1991.40    1    1
#
#    treat  propensity_score    weight
# 1      0          0.557221  1.794619
# 2      1          0.386939  2.584384
# 3      0          0.595422  1.679481
# 4      0          0.598786  1.670045
# 5      1          0.360843  2.771291

# %%
(lalonde[lalonde['treat'] == 1].mean() - lalonde[lalonde['treat'] == 0].mean())['re78']
# Out:
# 1794.3430848752569

# %%
(do_df[do_df['treat'] == 1].mean() - do_df[do_df['treat'] == 0].mean())['re78']
# Out:
# 1878.1750573690942

# %%
import numpy as np
1.96*np.sqrt((do_df[do_df['treat'] == 1].var()/len(do_df[do_df['treat'] == 1])) +
             (do_df[do_df['treat'] == 0].var()/len(do_df[do_df['treat'] == 0])))['re78']
# Out:
# 1359.3724330579473

# %%
print(do_df['re78'].describe())
print('-----------------')
lalonde['re78'].describe()
# Out:
# count      445.000000
# mean      6109.881494
# std       7349.357282
# min          0.000000
# 25%          0.000000
# 50%       4196.380000
# 75%       9371.040000
# max      60307.900000
# Name: re78, dtype: float64
# -----------------
# count      445.000000
# mean      5300.765138
# std       6631.493362
# min          0.000000
# 25%          0.000000
# 50%       3701.810000
# 75%       8124.720000
# max      60307.900000
# Name: re78, dtype: float64

# %%
# %matplotlib inline
import seaborn as sns

sns.barplot(data=lalonde, x='treat', y='re78')

# %%
sns.barplot(data=do_df, x='treat', y='re78')

# %%
do_df = lalonde.causal.do(x={'treat': 1},
                          outcome='re78',
                          common_causes=['nodegr', 'black', 'hisp', 'age', 'educ', 'married'],
                          variable_types={'age': 'c', 'educ':'c', 'black': 'd', 'hisp': 'd',
                                          'married': 'd', 'nodegr': 'd','re78': 'c', 'treat': 'b'})
# Out:
# WARNING:dowhy.causal_model:Causal Graph not provided. DoWhy will construct a graph based on data inputs.
# INFO:dowhy.causal_graph:If this is observed data (not from a randomized experiment), there might always be missing confounders. Adding a node named "Unobserved Confounders" to reflect this.
# INFO:dowhy.causal_model:Model to find the causal effect of treatment ['treat'] on outcome ['re78']
# INFO:dowhy.causal_identifier:Common causes of treatment and outcome:['married', 'educ', 'black', 'hisp', 'nodegr', 'age', 'U']
# WARNING:dowhy.causal_identifier:If this is observed data (not from a randomized experiment), there might always be missing confounders. Causal effect cannot be identified perfectly.
# WARN: Do you want to continue by ignoring any unobserved confounders? (use proceed_when_unidentifiable=True to disable this prompt) [y/n] y
# INFO:dowhy.causal_identifier:Instrumental variables for treatment and outcome:[]
# INFO:dowhy.do_sampler:Using WeightingSampler for do sampling.
# INFO:dowhy.do_sampler:Caution: do samplers assume iid data.

# %%
do_df.head()
# Out:
#    age  educ  black  hisp  married  nodegr     re74     re75      re78  u74  \
# 1   24    10      1     0        0       1     0.00     0.00      0.00    1
# 2   22     9      1     0        0       1  2192.88  3836.99   3462.56    0
# 3   22    11      1     0        0       1     0.00     0.00   6456.70    1
# 4   26    11      1     0        0       1     0.00     0.00  17231.00    1
# 5   18     9      1     0        0       1     0.00  3287.38   5010.34    1
#
#    u75  treat  propensity_score    weight
# 1    1      1          0.372589  2.683921
# 2    0      1          0.381319  2.622477
# 3    1      1          0.357755  2.795209
# 4    1      1          0.363942  2.747692
# 5    0      1          0.375011  2.666590
