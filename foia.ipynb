# %%
import pandas as pd

# %%
df = pd.read_csv("foia_up_to_150k_CA.csv")
df.head()
# Out:
#    LoanAmount        City State      Zip  NAICSCode  \
# 0   149999.98     FREEDOM    CA  95019.0   722511.0
# 1   149999.98  SANTA CRUZ    CA  95060.0   722511.0
# 2   149999.00   CALABASAS    CA  91302.0   999990.0
# 3   149999.00    VAN NUYS    CA  91406.0   443142.0
# 4   149999.00     CYPRESS    CA  90630.0   531210.0
#
#                       BusinessType RaceEthnicity      Gender      Veteran  \
# 0              Sole Proprietorship    Unanswered  Male Owned   Unanswered
# 1  Limited  Liability Company(LLC)    Unanswered  Male Owned  Non-Veteran
# 2  Limited  Liability Company(LLC)    Unanswered  Unanswered   Unanswered
# 3                      Corporation    Unanswered  Unanswered   Unanswered
# 4         Subchapter S Corporation    Unanswered  Unanswered   Unanswered
#
#   NonProfit  JobsRetained DateApproved                  Lender       CD
# 0       NaN          30.0   04/29/2020  Santa Cruz County Bank  CA - 20
# ...
